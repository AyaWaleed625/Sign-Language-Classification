# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (16,16))
img = plt.imread('amer_sign2.png')
plt.imshow(img)
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import random
from sklearn.model_selection import train_test_split
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPool2D, Flatten, Dense, Dropout
import warnings

sns.set()
# %matplotlib inline
warnings.filterwarnings("ignore")

# %%
df_train = pd.read_csv('sign_mnist_train.csv')
df_train.head(-5)
# Out:
#        label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0          3     107     118     127     134     139     143     146     150
# 1          6     155     157     156     156     156     157     156     158
# 2          2     187     188     188     187     187     186     187     188
# 3          2     211     211     212     212     211     210     211     210
# 4         13     164     167     170     172     176     179     180     184
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 27445     14     167     169     170     171     171     172     172     172
# 27446     19     133     135     138     141     143     144     144     145
# 27447     11     170     172     175     177     179     182     185     186
# 27448     12     149     151     153     157     159     161     164     165
# 27449     20     162     168     172     176     179     183     184     185
#
#        pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  \
# 0         153  ...       207       207       207       207       206
# 1         158  ...        69       149       128        87        94
# 2         187  ...       202       201       200       199       198
# 3         210  ...       235       234       233       231       230
# 4         185  ...        92       105       105       108       133
# ...       ...  ...       ...       ...       ...       ...       ...
# 27445     171  ...       215       215       211       208       211
# 27446     145  ...         0         0         1         4         4
# 27447     187  ...       221       228       229       228       229
# 27448     168  ...       108       165       167       163       159
# 27449     188  ...       235       234       234       233       231
#
#        pixel780  pixel781  pixel782  pixel783  pixel784
# 0           206       206       204       203       202
# 1           163       175       103       135       149
# 2           199       198       195       194       195
# 3           226       225       222       229       163
# 4           163       157       163       164       179
# ...         ...       ...       ...       ...       ...
# 27445       201       167       119        75        48
# 27446         0         0         0         0         0
# 27447       229       227       228       227       227
# 27448       153       147       148       139       196
# 27449       229       228       228       227       226
#
# [27450 rows x 785 columns]

# %%
df_test = pd.read_csv('sign_mnist_test.csv')
df_test.head(-5)
# Out:
#       label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0         6     149     149     150     150     150     151     151     150
# 1         5     126     128     131     132     133     134     135     135
# 2        10      85      88      92      96     105     123     135     143
# 3         0     203     205     207     206     207     209     210     209
# 4         3     188     191     193     195     199     201     202     203
# ...     ...     ...     ...     ...     ...     ...     ...     ...     ...
# 7162     10     130     131     131     134     133     135     137     136
# 7163      4     158     161     165     169     172     175     177     179
# 7164     14     141     144     146     149     153     156     158     161
# 7165      8     158     160     160     161     161     161     164     162
# 7166     12     169     173     177     181     183     186     189     191
#
#       pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 0        151  ...       138       148       127        89        82        96
# 1        136  ...        47       104       194       183       186       184
# 2        147  ...        68       166       242       227       230       227
# 3        210  ...       154       248       247       248       253       236
# 4        203  ...        26        40        64        48        29        46
# ...      ...  ...       ...       ...       ...       ...       ...       ...
# 7162     136  ...       128       106       107        63        11       147
# 7163     181  ...        78       122       141       141       141       140
# 7164     161  ...       199       203       202       201       201       201
# 7165     162  ...       177       178       176       174       173       172
# 7166     194  ...        36        27        14        35        40        15
#
#       pixel781  pixel782  pixel783  pixel784
# 0          106       112       120       107
# 1          184       184       182       180
# 2          226       225       224       222
# 3          230       240       253       255
# 4           49        46        46        53
# ...        ...       ...       ...       ...
# 7162       194       182       176       124
# 7163       141       142       143       144
# 7164       200       200       201       201
# 7165       171       169       169       167
# 7166         8        27        42        41
#
# [7167 rows x 785 columns]

# %%
plt.figure(figsize = (15,10))
sns.set_style("darkgrid")
sns.countplot(df_train['label'])
plt.show()

# %%
y_train = df_train['label']
df_train.drop(['label'], axis=1, inplace=True)
df_train.head(-5)
# Out:
#        pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  pixel9  \
# 0         107     118     127     134     139     143     146     150     153
# 1         155     157     156     156     156     157     156     158     158
# 2         187     188     188     187     187     186     187     188     187
# 3         211     211     212     212     211     210     211     210     210
# 4         164     167     170     172     176     179     180     184     185
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 27445     167     169     170     171     171     172     172     172     171
# 27446     133     135     138     141     143     144     144     145     145
# 27447     170     172     175     177     179     182     185     186     187
# 27448     149     151     153     157     159     161     164     165     168
# 27449     162     168     172     176     179     183     184     185     188
#
#        pixel10  ...  pixel775  pixel776  pixel777  pixel778  pixel779  \
# 0          156  ...       207       207       207       207       206
# 1          157  ...        69       149       128        87        94
# 2          186  ...       202       201       200       199       198
# 3          211  ...       235       234       233       231       230
# 4          186  ...        92       105       105       108       133
# ...        ...  ...       ...       ...       ...       ...       ...
# 27445      172  ...       215       215       211       208       211
# 27446      145  ...         0         0         1         4         4
# 27447      188  ...       221       228       229       228       229
# 27448      171  ...       108       165       167       163       159
# 27449      190  ...       235       234       234       233       231
#
#        pixel780  pixel781  pixel782  pixel783  pixel784
# 0           206       206       204       203       202
# 1           163       175       103       135       149
# 2           199       198       195       194       195
# 3           226       225       222       229       163
# 4           163       157       163       164       179
# ...         ...       ...       ...       ...       ...
# 27445       201       167       119        75        48
# 27446         0         0         0         0         0
# 27447       229       227       228       227       227
# 27448       153       147       148       139       196
# 27449       229       228       228       227       226
#
# [27450 rows x 784 columns]

# %%
y_test = df_test['label']
df_test.drop(['label'], axis=1, inplace=True)
df_test.head(-5)
# Out:
#       pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  pixel9  \
# 0        149     149     150     150     150     151     151     150     151
# 1        126     128     131     132     133     134     135     135     136
# 2         85      88      92      96     105     123     135     143     147
# 3        203     205     207     206     207     209     210     209     210
# 4        188     191     193     195     199     201     202     203     203
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 7162     130     131     131     134     133     135     137     136     136
# 7163     158     161     165     169     172     175     177     179     181
# 7164     141     144     146     149     153     156     158     161     161
# 7165     158     160     160     161     161     161     164     162     162
# 7166     169     173     177     181     183     186     189     191     194
#
#       pixel10  ...  pixel775  pixel776  pixel777  pixel778  pixel779  \
# 0         152  ...       138       148       127        89        82
# 1         138  ...        47       104       194       183       186
# 2         152  ...        68       166       242       227       230
# 3         209  ...       154       248       247       248       253
# 4         203  ...        26        40        64        48        29
# ...       ...  ...       ...       ...       ...       ...       ...
# 7162      137  ...       128       106       107        63        11
# 7163      184  ...        78       122       141       141       141
# 7164      161  ...       199       203       202       201       201
# 7165      161  ...       177       178       176       174       173
# 7166      195  ...        36        27        14        35        40
#
#       pixel780  pixel781  pixel782  pixel783  pixel784
# 0           96       106       112       120       107
# 1          184       184       184       182       180
# 2          227       226       225       224       222
# 3          236       230       240       253       255
# 4           46        49        46        46        53
# ...        ...       ...       ...       ...       ...
# 7162       147       194       182       176       124
# 7163       140       141       142       143       144
# 7164       201       200       200       201       201
# 7165       172       171       169       169       167
# 7166        15         8        27        42        41
#
# [7167 rows x 784 columns]

# %%
size  = 28
channels = 1
batch = 128
epochs = 50

# %%
X_train = df_train.values.reshape(df_train.shape[0], size, size, channels)
X_test = df_test.values.reshape(df_test.shape[0], size, size, channels)

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
# Out:
# X_train shape: (27455, 28, 28, 1)
# X_test shape: (7172, 28, 28, 1)

# %%
datagen = ImageDataGenerator(rescale=1./255,
                             zoom_range=0.2,
                             width_shift_range=.2, height_shift_range=.2,
                             rotation_range=30,
                             brightness_range=[0.8, 1.2],
                             horizontal_flip=True)

datagenRescale = ImageDataGenerator(rescale=1./255)

X_train = datagen.flow(X_train, y_train, batch_size=batch)

X_test = datagenRescale.flow(X_test, y_test)

# %%
alphabet = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
plt.figure(figsize=(15, 15))
for i in range(9):
    plt.subplot(3, 3, i+1)
    for X_batch, Y_batch in X_train:
        image = X_batch[i]
        plt.imshow(image, cmap='gray')
        plt.xlabel(alphabet[Y_batch[i]])
        break
plt.show()

# %%
checkpoint_filepath = 'best_model.hdf5'

callback_checkpoint = ModelCheckpoint(filepath=checkpoint_filepath, save_weights_only=False, monitor='val_accuracy', mode='max', save_best_only=True)
callback_learningrate = ReduceLROnPlateau(monitor='loss', mode='min', min_delta=0.01, patience=3, factor=.75, min_lr=0.00001, verbose=1)

callbacks = [callback_checkpoint, callback_learningrate]

# %%
Model = Sequential([Conv2D(filters=32,  kernel_size=(3,3), activation="relu", input_shape=(size,size,channels)),
                    MaxPool2D(2,2, padding='same'),
                    Dropout(0.2),
                 
                    Conv2D(filters=128,  kernel_size=(3,3), activation="relu"),
                    MaxPool2D(2,2, padding='same'),
                    Dropout(0.2),
                
                    Conv2D(filters=512, kernel_size=(3,3), activation="relu"),
                    MaxPool2D(2,2, padding='same'),
                    Dropout(0.2),
                    
                    
                    Flatten(),
                    
                    Dense(units=4096, activation="relu"),                 
                    Dropout(0.2),
                    
                    Dense(units=1024, activation="relu"),
                    Dropout(0.2),
                                  
                    Dense(units=256, activation="relu"),
                    Dropout(0.2),
                    
                    Dense(units=25, activation="softmax"),
])

Model.compile(optimizer='adam', loss="sparse_categorical_crossentropy", metrics=["accuracy"])


Model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  dropout (Dropout)           (None, 13, 13, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 128)       36992
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 128)         0
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 512)         590336
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 2, 512)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 2, 2, 512)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 4096)              8392704
#
#  dropout_3 (Dropout)         (None, 4096)              0
#
#  dense_1 (Dense)             (None, 1024)              4195328
#
#  dropout_4 (Dropout)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 256)               262400
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 25)                6425
#
# =================================================================
# Total params: 13,484,505
# Trainable params: 13,484,505
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = Model.fit(X_train, validation_data=X_test, epochs=epochs, callbacks=callbacks)
# Out:
# Epoch 1/50
# 215/215 [==============================] - 57s 261ms/step - loss: 3.1573 - accuracy: 0.0523 - val_loss: 2.9600 - val_accuracy: 0.0523 - lr: 0.0010
# Epoch 2/50
# 215/215 [==============================] - 53s 246ms/step - loss: 2.6254 - accuracy: 0.1587 - val_loss: 1.8646 - val_accuracy: 0.3225 - lr: 0.0010
# Epoch 3/50
# 215/215 [==============================] - 52s 243ms/step - loss: 1.8161 - accuracy: 0.3836 - val_loss: 0.9657 - val_accuracy: 0.6265 - lr: 0.0010
# Epoch 4/50
# 215/215 [==============================] - 58s 270ms/step - loss: 1.3152 - accuracy: 0.5439 - val_loss: 0.6997 - val_accuracy: 0.7383 - lr: 0.0010
# Epoch 5/50
# 215/215 [==============================] - 53s 248ms/step - loss: 1.0422 - accuracy: 0.6328 - val_loss: 0.4430 - val_accuracy: 0.8562 - lr: 0.0010
# Epoch 6/50
# 215/215 [==============================] - 54s 250ms/step - loss: 0.8652 - accuracy: 0.6966 - val_loss: 0.3219 - val_accuracy: 0.9080 - lr: 0.0010
# Epoch 7/50
# 215/215 [==============================] - 55s 256ms/step - loss: 0.7567 - accuracy: 0.7332 - val_loss: 0.2500 - val_accuracy: 0.9296 - lr: 0.0010
# Epoch 8/50
# 215/215 [==============================] - 54s 250ms/step - loss: 0.6588 - accuracy: 0.7697 - val_loss: 0.2215 - val_accuracy: 0.9253 - lr: 0.0010
# Epoch 9/50
# 215/215 [==============================] - 56s 262ms/step - loss: 0.5876 - accuracy: 0.7950 - val_loss: 0.1689 - val_accuracy: 0.9359 - lr: 0.0010
# Epoch 10/50
# 215/215 [==============================] - 57s 266ms/step - loss: 0.5255 - accuracy: 0.8186 - val_loss: 0.1034 - val_accuracy: 0.9632 - lr: 0.0010
# Epoch 11/50
# 215/215 [==============================] - 57s 266ms/step - loss: 0.4884 - accuracy: 0.8322 - val_loss: 0.0808 - val_accuracy: 0.9647 - lr: 0.0010
# Epoch 12/50
# 215/215 [==============================] - 55s 254ms/step - loss: 0.4596 - accuracy: 0.8418 - val_loss: 0.0827 - val_accuracy: 0.9752 - lr: 0.0010
# Epoch 13/50
# 215/215 [==============================] - 53s 247ms/step - loss: 0.4271 - accuracy: 0.8527 - val_loss: 0.0600 - val_accuracy: 0.9813 - lr: 0.0010
# Epoch 14/50
# 215/215 [==============================] - 53s 247ms/step - loss: 0.4013 - accuracy: 0.8653 - val_loss: 0.0564 - val_accuracy: 0.9827 - lr: 0.0010
# Epoch 15/50
# 215/215 [==============================] - 55s 254ms/step - loss: 0.3739 - accuracy: 0.8734 - val_loss: 0.0444 - val_accuracy: 0.9884 - lr: 0.0010
# Epoch 16/50
# 215/215 [==============================] - 57s 263ms/step - loss: 0.3581 - accuracy: 0.8802 - val_loss: 0.0499 - val_accuracy: 0.9820 - lr: 0.0010
# Epoch 17/50
# 215/215 [==============================] - 65s 302ms/step - loss: 0.3391 - accuracy: 0.8842 - val_loss: 0.0339 - val_accuracy: 0.9900 - lr: 0.0010
# Epoch 18/50
# 215/215 [==============================] - 65s 304ms/step - loss: 0.3229 - accuracy: 0.8900 - val_loss: 0.0640 - val_accuracy: 0.9773 - lr: 0.0010
# Epoch 19/50
# 215/215 [==============================] - 67s 311ms/step - loss: 0.3058 - accuracy: 0.8968 - val_loss: 0.0158 - val_accuracy: 0.9987 - lr: 0.0010
# Epoch 20/50
# 215/215 [==============================] - 68s 315ms/step - loss: 0.3039 - accuracy: 0.8979 - val_loss: 0.0293 - val_accuracy: 0.9876 - lr: 0.0010
# Epoch 21/50
# 215/215 [==============================] - 70s 328ms/step - loss: 0.2886 - accuracy: 0.9049 - val_loss: 0.0249 - val_accuracy: 0.9922 - lr: 0.0010
# Epoch 22/50
# 215/215 [==============================] - 77s 356ms/step - loss: 0.2807 - accuracy: 0.9055 - val_loss: 0.0224 - val_accuracy: 0.9943 - lr: 0.0010
# Epoch 23/50
# 215/215 [==============================] - 77s 358ms/step - loss: 0.2681 - accuracy: 0.9103 - val_loss: 0.0270 - val_accuracy: 0.9891 - lr: 0.0010
# Epoch 24/50
# 215/215 [==============================] - 77s 360ms/step - loss: 0.2660 - accuracy: 0.9126 - val_loss: 0.0252 - val_accuracy: 0.9922 - lr: 0.0010
# Epoch 25/50
# 215/215 [==============================] - 75s 349ms/step - loss: 0.2524 - accuracy: 0.9150 - val_loss: 0.0121 - val_accuracy: 0.9982 - lr: 0.0010
# Epoch 26/50
# 215/215 [==============================] - 63s 291ms/step - loss: 0.2455 - accuracy: 0.9189 - val_loss: 0.0212 - val_accuracy: 0.9932 - lr: 0.0010
# Epoch 27/50
# 215/215 [==============================] - 56s 260ms/step - loss: 0.2290 - accuracy: 0.9231 - val_loss: 0.0136 - val_accuracy: 0.9971 - lr: 0.0010
# Epoch 28/50
# 215/215 [==============================] - 54s 251ms/step - loss: 0.2353 - accuracy: 0.9218 - val_loss: 0.0143 - val_accuracy: 0.9957 - lr: 0.0010
# Epoch 29/50
# 215/215 [==============================] - 53s 247ms/step - loss: 0.2263 - accuracy: 0.9255 - val_loss: 0.0181 - val_accuracy: 0.9905 - lr: 0.0010
# Epoch 30/50
# 215/215 [==============================] - ETA: 0s - loss: 0.2222 - accuracy: 0.9243
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0007500000356230885.
# 215/215 [==============================] - 54s 250ms/step - loss: 0.2222 - accuracy: 0.9243 - val_loss: 0.0141 - val_accuracy: 0.9968 - lr: 0.0010
# Epoch 31/50
# 215/215 [==============================] - 54s 252ms/step - loss: 0.2067 - accuracy: 0.9319 - val_loss: 0.0080 - val_accuracy: 0.9990 - lr: 7.5000e-04
# Epoch 32/50
# 215/215 [==============================] - 57s 266ms/step - loss: 0.1872 - accuracy: 0.9403 - val_loss: 0.0053 - val_accuracy: 0.9996 - lr: 7.5000e-04
# Epoch 33/50
# 215/215 [==============================] - 53s 248ms/step - loss: 0.1862 - accuracy: 0.9383 - val_loss: 0.0083 - val_accuracy: 0.9996 - lr: 7.5000e-04
# Epoch 34/50
# 215/215 [==============================] - 54s 250ms/step - loss: 0.1839 - accuracy: 0.9386 - val_loss: 0.0085 - val_accuracy: 0.9983 - lr: 7.5000e-04
# Epoch 35/50
# 215/215 [==============================] - ETA: 0s - loss: 0.1862 - accuracy: 0.9390
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0005625000048894435.
# 215/215 [==============================] - 55s 255ms/step - loss: 0.1862 - accuracy: 0.9390 - val_loss: 0.0079 - val_accuracy: 0.9979 - lr: 7.5000e-04
# Epoch 36/50
# 215/215 [==============================] - 54s 252ms/step - loss: 0.1621 - accuracy: 0.9443 - val_loss: 0.0047 - val_accuracy: 0.9999 - lr: 5.6250e-04
# Epoch 37/50
# 215/215 [==============================] - 53s 247ms/step - loss: 0.1564 - accuracy: 0.9477 - val_loss: 0.0101 - val_accuracy: 0.9972 - lr: 5.6250e-04
# Epoch 38/50
# 215/215 [==============================] - 53s 249ms/step - loss: 0.1545 - accuracy: 0.9498 - val_loss: 0.0075 - val_accuracy: 0.9989 - lr: 5.6250e-04
# Epoch 39/50
# 215/215 [==============================] - 53s 248ms/step - loss: 0.1482 - accuracy: 0.9506 - val_loss: 0.0041 - val_accuracy: 0.9999 - lr: 5.6250e-04
# Epoch 40/50
# 215/215 [==============================] - 55s 255ms/step - loss: 0.1445 - accuracy: 0.9532 - val_loss: 0.0035 - val_accuracy: 0.9997 - lr: 5.6250e-04
# Epoch 41/50
# 215/215 [==============================] - 54s 252ms/step - loss: 0.1390 - accuracy: 0.9545 - val_loss: 0.0039 - val_accuracy: 0.9994 - lr: 5.6250e-04
# Epoch 42/50
# 215/215 [==============================] - ETA: 0s - loss: 0.1507 - accuracy: 0.9501
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0004218749818392098.
# 215/215 [==============================] - 54s 249ms/step - loss: 0.1507 - accuracy: 0.9501 - val_loss: 0.0031 - val_accuracy: 1.0000 - lr: 5.6250e-04
# Epoch 43/50
# 215/215 [==============================] - 53s 248ms/step - loss: 0.1311 - accuracy: 0.9573 - val_loss: 0.0033 - val_accuracy: 0.9999 - lr: 4.2187e-04
# Epoch 44/50
# 215/215 [==============================] - 55s 257ms/step - loss: 0.1320 - accuracy: 0.9568 - val_loss: 0.0049 - val_accuracy: 0.9994 - lr: 4.2187e-04
# Epoch 45/50
# 215/215 [==============================] - 53s 247ms/step - loss: 0.1252 - accuracy: 0.9584 - val_loss: 0.0037 - val_accuracy: 0.9990 - lr: 4.2187e-04
# Epoch 46/50
# 215/215 [==============================] - ETA: 0s - loss: 0.1236 - accuracy: 0.9603
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.00031640623637940735.
# 215/215 [==============================] - 53s 247ms/step - loss: 0.1236 - accuracy: 0.9603 - val_loss: 0.0036 - val_accuracy: 1.0000 - lr: 4.2187e-04
# Epoch 47/50
# 215/215 [==============================] - 56s 261ms/step - loss: 0.1175 - accuracy: 0.9614 - val_loss: 0.0021 - val_accuracy: 1.0000 - lr: 3.1641e-04
# Epoch 48/50
# 215/215 [==============================] - 59s 273ms/step - loss: 0.1148 - accuracy: 0.9622 - val_loss: 0.0017 - val_accuracy: 1.0000 - lr: 3.1641e-04
# Epoch 49/50
# 215/215 [==============================] - 57s 265ms/step - loss: 0.1135 - accuracy: 0.9623 - val_loss: 0.0015 - val_accuracy: 0.9999 - lr: 3.1641e-04
# Epoch 50/50
# 215/215 [==============================] - ETA: 0s - loss: 0.1113 - accuracy: 0.9640
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.00023730468819849193.
# 215/215 [==============================] - 55s 257ms/step - loss: 0.1113 - accuracy: 0.9640 - val_loss: 0.0034 - val_accuracy: 0.9990 - lr: 3.1641e-04

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(len(acc))

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
score = Model.evaluate(X_test) 

print('Test loss:', score[0]) 
print('Test accuracy:', score[1])
# Out:
# 225/225 [==============================] - 4s 17ms/step - loss: 0.0034 - accuracy: 0.9990
# Test loss: 0.0034245247952640057
# Test accuracy: 0.999023973941803

# %%
df_test = pd.read_csv('sign_mnist_test.csv')
y_test = df_test['label']
df_test.drop(['label'], axis=1, inplace=True)
X_test = df_test.values.reshape(df_test.shape[0], size, size, channels)

# %%
y_pred = np.argmax(Model.predict(X_test),axis = 1)
# Out:
# 225/225 [==============================] - 4s 17ms/step

# %%
from sklearn.metrics import confusion_matrix
CM = confusion_matrix(y_test, y_pred)
plt.figure(figsize = (15,15))
sns.heatmap(CM, annot=True, cmap="Greens", fmt = 'g')
plt.xlabel("Predicted Classes")
plt.ylabel("True Classes")
plt.title("Confusion Matrix")
plt.show()

# %%
#test

plt.figure(figsize=(15,15))
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(X_test[i],cmap='gray')
    plt.ylabel(f"True: {alphabet[y_test[i]]}")
    plt.xlabel(f"Predicted: {alphabet[y_pred[i]]}")
    
plt.show()
